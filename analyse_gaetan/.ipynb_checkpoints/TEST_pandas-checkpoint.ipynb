# %%
from func_search import *
from func_def_class import *
from func_taux_transm import *
import os
from path import Path
import csv
#import matplotlib.pyplot as plt 
import ConfigParser
from struct import unpack
import re

# %%
from pandas import *
import pandas as pd
import sys
import matplotlib.pyplot as plt
from numpy import random

# %%
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]

# %%
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 578), ('Mel', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
df.dtypes
# Out:
# Names     object
# Births     int64
# dtype: object

# %%
# Method 1:
Sorted = df.sort_values(['Births'], ascending=False)
Sorted.head(2)
# Out:
#   Names  Births
# 4   Mel     973
# 0   Bob     968

# %%
random.seed(500)
random_names = [names[random.randint(low=0,high=len(names))] for i in range(1000)]

# Print first 10 records
random_names[:10]
# Out:
# ['Mary',
#  'Jessica',
#  'Jessica',
#  'Bob',
#  'Jessica',
#  'Jessica',
#  'Jessica',
#  'Mary',
#  'Mary',
#  'Mary']

# %%
# The number of births per name for the year 1880
births = [random.randint(low=0,high=1000) for i in range(1000)]
births[:10]
# Out:
# [905, 52, 796, 217, 874, 161, 605, 230, 593, 464]

# %%
BabyDataSet = list(zip(random_names,births))
BabyDataSet[:10]
# Out:
# [('Mary', 905),
#  ('Jessica', 52),
#  ('Jessica', 796),
#  ('Bob', 217),
#  ('Jessica', 874),
#  ('Jessica', 161),
#  ('Jessica', 605),
#  ('Mary', 230),
#  ('Mary', 593),
#  ('Mary', 464)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
# Out:
#        Names  Births
# 0       Mary     905
# 1    Jessica      52
# 2    Jessica     796
# 3        Bob     217
# 4    Jessica     874
# 5    Jessica     161
# 6    Jessica     605
# 7       Mary     230
# 8       Mary     593
# 9       Mary     464
# 10      John     444
# 11       Bob     392
# 12       Bob     576
# 13      Mary     563
# 14      Mary     130
# 15      John     823
# 16       Mel     419
# 17      Mary       6
# 18       Mel     641
# 19      John     559
# 20      John     182
# 21       Mel     240
# 22   Jessica     925
# 23      John     317
# 24   Jessica     348
# 25      Mary     191
# 26      Mary     836
# 27      John     524
# 28   Jessica     913
# 29       Bob     524
# ..       ...     ...
# 970  Jessica     720
# 971  Jessica     196
# 972  Jessica     152
# 973      Mel     203
# 974      Bob     583
# 975     John     466
# 976     Mary     839
# 977      Bob     113
# 978     John     544
# 979      Mel      55
# 980  Jessica     952
# ...

# %%
df.to_csv('data_csv/births1880.csv',index=False,header=False)

# %%
df_tx = pd.read_csv(r'data_csv/pkt_tx.csv', dtype=str)
df_tx["asn"] = df_tx["asn"].astype(int)
df_tx
# Out:
#                           time  addr comp     asn statType trackinstance  \
# 0      2017-04-07 09:30:58,882  b868   22     730        3             0
# 1      2017-04-07 09:31:07,538  b868   12    1015        3             0
# 2      2017-04-07 09:31:09,884  b868   22    1096        3             0
# 3      2017-04-07 09:31:14,754  8772   15    1258        3             0
# 4      2017-04-07 09:31:14,754  b381   15    1258        3             0
# 5      2017-04-07 09:31:14,755  1162   12    1258        3             0
# 6      2017-04-07 09:31:15,477  1162   15    1282        3             0
# 7      2017-04-07 09:31:15,990  b381   15    1299        3             0
# 8      2017-04-07 09:31:17,191  8772   15    1339        3             0
# 9      2017-04-07 09:31:18,453  b381   22    1380        3             0
# 10     2017-04-07 09:31:18,782  1162   22    1392        3             0
# 11     2017-04-07 09:31:20,800  8772   12    1459        3             0
# ...

# %%
df_rx = pd.read_csv(r'data_csv/pkt_rx.csv', dtype=str)
df_rx["asn"] = df_rx["asn"].astype(int)
df_rx
# Out:
#                           time  addr comp     asn statType trackinstance  \
# 0      2017-04-07 09:31:07,577  8772    9    1015        4             0
# 1      2017-04-07 09:31:07,577  b381    9    1015        4             0
# 2      2017-04-07 09:31:07,578  1162    9    1015        4             0
# 3      2017-04-07 09:31:07,582  c280    9    1015        4             0
# 4      2017-04-07 09:31:09,884  b381    9    1096        4             0
# 5      2017-04-07 09:31:09,886  1162    9    1096        4             0
# 6      2017-04-07 09:31:09,886  8772    9    1096        4             0
# 7      2017-04-07 09:31:15,988  b868    9    1299        4             0
# 8      2017-04-07 09:31:17,190  b868    9    1339        4             4
# 9      2017-04-07 09:31:18,424  1162    9    1380        4             0
# 10     2017-04-07 09:31:22,088  b381    9    1502        4             0
# 11     2017-04-07 09:31:22,089  c280    9    1502        4             0
# ...

# %%
print len(df2.loc[df2['asn']=="1015"])
df2.loc[(df2['asn']=="1015") & (df2['addr']=='8772')]
#for i in df2.loc[df2['asn']=='1015']:
 #   print "test"
    
if df2.loc[(df2['asn']=="1015") & (df2['addr']=='8772')]["asn"].str.endswith("5")[0]:
    print 'oui'

df_tx.dtypes
#.endswith("5")

#get_l2Src(line).endswith(addr_1)
# Out:
# 4
# oui
# time             object
# addr             object
# comp             object
# asn               int64
# statType         object
# trackinstance    object
# trackowner       object
# length           object
# frameType        object
# slotOffset       object
# frequency        object
# l2Dest           object
# txpower          object
# numTxAttempts    object
# queuePos         object
# succes_rx        object
# succes_ack       object
# dtype: object

# %%
df_tx.loc[ (df_tx['asn'] <= 1015) ]
# Out:
#                       time  addr comp   asn statType trackinstance  \
# 0  2017-04-07 09:30:58,882  b868   22   730        3             0
# 1  2017-04-07 09:31:07,538  b868   12  1015        3             0
#
#          trackowner length            frameType slotOffset frequency  \
# 0  0000000000000000     47    IEEE154_TYPE_DATA        121        16
# 1  0000000000000000     67  IEEE154_TYPE_BEACON          0        16
#
#              l2Dest txpower numTxAttempts queuePos succes_rx succes_ack  \
# 0  ffffffffffffffff      31             1        0         0          0
# 1  ffffffffffffffff      31             1        0         0          0
#
#   list_rx
# 0     NaN
# 1     NaN

# %%
# Out:
# 4 ['8772', 'b381', '1162', 'c280']
# [0, 1, 2, 3]
# True
# True
# True
# True
