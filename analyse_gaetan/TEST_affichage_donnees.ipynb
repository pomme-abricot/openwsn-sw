# %%
from func_search import *
from func_taux_transm import *
from func_def_class import *
import matplotlib.pyplot as plt
#import networkx as nx

#import mlpy
#import matplotlib.cm as cm

#from dtw import dtw
#from numpy.linalg import norm

# %%
liste_neuds = get_all_addr("data/exp_8.log")
for n in liste_neuds:
    t = transmission_ratio_addr(n,5000, 500)
    plt.plot(t,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
    plt.xlabel(n)
    plt.ylabel('taux de transmission')
    plt.ylim((-2,2))
    #plt.xlim((0,200))
    #plt.savefig('plot_comp1.png')
    plt.show()

# %%
liste_neuds = get_all_addr("data/exp_10.log")
for n in liste_neuds:
    t = transmission_ratio_addr(n,5000, 500)
    plt.plot(t,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
    plt.xlabel(n)
    plt.ylabel('taux de transmission')
    plt.ylim((-2,2))
    #plt.xlim((0,200))
    #plt.savefig('plot_comp1.png')
    plt.show()

# %%
t1, t2 = transmission_ratio_flow("8772","b868",50000,1000)
plt.plot(t1,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
plt.xlabel("8772")
plt.ylabel('taux de transmission')
plt.ylim((-1,1))
#plt.xlim((0,200))
#plt.savefig('plot_comp1.png')
plt.show()

plt.plot(t2,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
plt.xlabel("b868")
plt.ylabel('taux de transmission')
plt.ylim((-1,1))
#plt.xlim((0,200))
#plt.savefig('plot_comp1.png')
plt.show()


t3, t4 = transmission_ratio_flow("b868","1162",50000,500)
plt.plot(t3,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
plt.xlabel("b868")
plt.ylabel('taux de transmission')
plt.ylim((-1,1))
#plt.xlim((0,200))
#plt.savefig('plot_comp1.png')
plt.show()

plt.plot(t4,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
plt.xlabel("1162")
plt.ylabel('taux de transmission')
plt.ylim((-1,1))
#plt.xlim((0,200))
#plt.savefig('plot_comp1.png')
plt.show()

# %%
t = transmission_ratio_flow_node("8772","c280",50000,1000)
plt.plot(t,'-o', ms=5, lw=2, alpha=0.7, mfc='red')
plt.xlabel("8772")
plt.ylabel('taux de transmission')
plt.ylim((-1,1))
#plt.xlim((0,200))
#plt.savefig('plot_comp1.png')
plt.show()
